# %% [markdown]
# # Assignment 1 — Making Sense of Northgate through Visualization
# **INFO 4670 · Data Analysis and Knowledge Discovery**  ·  **Due: Sunday, 11:59 PM**
#
# **Name:** \_\_\_\_\_\_\_\_    **Date:** \_\_\_\_\_\_\_\_
#
# **The situation.** The Provost's question stands: *which students are struggling, and can we see it earlier?* This week you answer it the way analysts do — not by reading rows, but by drawing the data. Every chart below is built by **adapting code from the Guided notebook**; the intellectual work is choosing the right chart and reading it honestly.
#
# **For every chart you make, you must:**
# 1. **Choose** the chart type that fits the variable(s) and the question.
# 2. **Build** it in Colab from the Northgate files.
# 3. **Label** it fully — title, axis labels, and units/legend. *An unlabeled chart is an unfinished chart.*
# 4. **Write a STAR story** underneath it — Scope · Track · Articulate · Respond (defined on the Concepts deck).
#
# **How to work:** run Setup and Load first. Then, for each question, copy the closest cell from the Guided notebook into the empty cell, adapt it, and fill in the STAR cell below it.
#
# **Submit:** push this notebook to GitHub and submit the **GitHub link** in Canvas. (See the setup doc: *Colab_GitHub_Setup_INFO4670_Fall2026*.)

# %% [markdown]
# ## Setup — run this first (you don't need to change it)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Northgate house style (optional, but keeps your charts consistent)
NAVY = "#22303A"
RUST = "#C0562F"
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"]   = (8, 5)
plt.rcParams["axes.titlesize"]   = 13
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## Load the data — run this, then look before you plot

# %%
# STEP 1 — get the data into this notebook. Pick ONE option, then run.
import pandas as pd
import os

DATA_DIR = "."   # OPTION 2 (default) · drag the 3 CSVs into the file panel on the left

# OPTION 1 · read from Google Drive — uncomment and edit the path:
# from google.colab import drive
# drive.mount("/content/drive")
# DATA_DIR = "/content/drive/MyDrive/.../Data"


students = pd.read_csv(os.path.join(DATA_DIR, "student_records.csv"))
weekly   = pd.read_csv(os.path.join(DATA_DIR, "weekly_activity.csv"))
students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# 1                   9.5      2023-10-19            0
# 2                  19.1      11/16/2022            0
# 3                   8.1      2024-05-03            0
# 4                   6.6      10/24/2022            0

# %%
# how many rows, which columns, what types?
students.info()

# %% [markdown]
# # Part A — Guided questions
# Build **one chart per question**. Each maps to one chart family from this week. Copy the closest Guided-notebook cell, adapt it, label it, then write its STAR story.

# %% [markdown]
# ### Q1 · One quantitative variable
# **How many hours per week do Northgate students work?** Describe what's typical, how spread out it is, and whether anyone stands apart.
# → *histogram* (add a *box plot* if it helps). Column: `work_hours_per_week` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
NAVY = "#22303A"
#
fig, ax = plt.subplots()
sns.histplot(data=students, x="work_hours_per_week", color=NAVY, ax=ax, kde=True)   # which chart? which column(s)?
ax.set_title("Distribution of Weekly Work Hours — Northgate Students")
ax.set_xlabel("Work Hours per Week")
ax.set_ylabel("Number of Students")
plt.show()

# --- your code below ---

# %% [markdown]
# **STAR story — Q1** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# S-The chart shows work hours per week for all Northgate students shown the student records.
#
# T-How many hours per week do Northgate students typically work, and how much does that vary?
#
# A-The distribution is relatively spread out more around the middle than a simple bell curve. No typical number. The chart shows many students working 0 hours, most are in the 10-25 hours per week range, and it falls back off around 30-40 hours per week. Curve shows good amount in the light-no work area, most in  the middle, and another good amount in the higher work area.
#
# R-There is a good spread around the whole chart. Odd because you dont expect that many students not putting in enough hours, and should be more of a bell curve with a higher peak of students in the middle.

# %% [markdown]
# ### Q2 · One categorical variable
# **How does enrollment compare across majors?**
# → *sorted bar chart*. Column: `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
NAVY = "#22303A"
major_order = students["major"].value_counts().index
#
fig, ax = plt.subplots()
sns.countplot(data=students, x="major", color=NAVY, ax=ax)   # which chart? which column(s)?
ax.set_title("Enrollment by Major for Northgate Students")
ax.set_xlabel("Major")
ax.set_ylabel("Number of Students")
plt.xticks(rotation=45, ha="right")
plt.show()

# --- your code below ---

# %% [markdown]
# **STAR story — Q2** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# S-The model shows the major for Northgate students from highest to lowest.
#
# T-How does enrollment compare across majors?
#
# A-Cybersecruity is by far the highest major. The next 3 are all around the same, followed by Data Science, Information Technology, and Information Science are all clustered close together around 280–285 students each. Then followed by Business Analytics at about 255 and Learning Technologies at about 210. Lastly, DataScience, Information Science, and Info Technology — each under 40 students.
#
# R-The same major is listed a few different times with slightly different spelling. This could throw off the numbers/accuracy of the chart. Dataset needs to be sorted a bit differently.

# %% [markdown]
# ### Q3 · A quantity, split by category
# **Does final GPA differ across majors?** Read the exceptions, not just the boxes.
# → *box plot per major*. Columns: `final_gpa` and `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

NAVY = "#22303A"

#
fig, ax = plt.subplots()
sns.boxplot(data=students, x="major", y="final_gpa", color=NAVY, ax=ax)   # which chart? which column(s)?
ax.set_title("Final GPA by Major — Northgate Students")
ax.set_xlabel("Major")
ax.set_ylabel("Final GPA")
plt.xticks(rotation=45, ha="right")
plt.show()

# --- your code below ---

# %% [markdown]
# **STAR story — Q3** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# S-This chart shows final gpa split by major for Northgate students.
#
# T-Does final GPA differ across majors?
#
# A-All the medians are roughly in the same area between 2.3-2.5. middle 50% for all majors generally sit between 1.8-2.8 gpa.Information Science has the widest spread box meaning students varied a lot in their gpa for that major.
#
# R-There are outliers of 0.0 gpa amongst almost every major, this is odd and unexpected. Is that possible or could it indicate withdrawl from the school, or a major change.

# %% [markdown]
# ### Q4 · Two quantitative variables
# **Is there a relationship between how far students commute and their final GPA?** Remember: *association is not causation.*
# → *scatterplot with a trend line*. Columns: `commute_miles` and `final_gpa` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

NAVY = "#22303A"

#
fig, ax = plt.subplots()
sns.regplot(data=students, x="commute_miles", y="final_gpa", color=NAVY, ax=ax)   # which chart? which column(s)?
ax.set_title("Commute Distance vs. Final GPA — Northgate Students")
ax.set_xlabel("Commute Distance (miles)")
ax.set_ylabel("Final GPA")
plt.show()

# --- your code below ---

# %% [markdown]
# **STAR story — Q4** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# S-This chart shows commute miles with final gpa for Northgate students.
#
# T-Is there a relationship between how far students commute and their final GPA?
#
# A-There's a clear downward trend line: GPA starts around 2.5 for students with very short commutes (near 0 miles) and slides down to roughly 0.8–1.0 for students commuting 70–80 miles. At short commute distances, distance tells you almost nothing about GPA. Meanwhile, it becomes obvious past 30–40 miles, where the cloud of points thins out and shifts consistently lower.
#
# R-Two things are odd first the row of 0.0 gpa students, again this is likely a problem with the dataset itself and not entirely accruate. Second is correlation does not equal causation. Commute distances isnt the only varibale these students could have health, work, or family responsibilites on top of their long commute.

# %% [markdown]
# ### Q5 · Over time
# **How does student engagement change across the semester?**
# → *line chart* of average weekly activity. Use the `weekly` table: `week` and `minutes_active` (you'll need to average by week first — see the Guided notebook).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

NAVY = "#22303A"



#
fig, ax = plt.subplots()
sns.lineplot(data=weekly, x="week", y="minutes_active", color=NAVY, ax=ax)   # which chart? which column(s)?
ax.set_title("Average Weekly Engagement Over the Semester — Northgate Students")
ax.set_xlabel("Week")
ax.set_ylabel("Average Minutes Active")
plt.show()

# --- your code below ---

# %% [markdown]
# **STAR story — Q5** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# S-This chart shows the average minutes active per week, averaged across all Northgate students during the semester.
#
# T-How does student engagement change across the semester?
#
# A-The average minutes active is stead for majority of the semester except for a significant drop during weeks 8-10. Which could mean a winter break or some other break where students are not required to be as active.
#
# R-One dramatic part was week 9 where the minutes active dipped very significantly almost done to zero. It shoots down to that and shoots back up there is ni gradual decline or incline. Meaning again most likely a break for the students.

# %% [markdown]
# # Part B — Your own question (open)
# Pose **one question of your own** about the Northgate students, choose the chart that answers it, build it, label it, and write its STAR story. Going beyond Part A is rewarded — a per-student line chart, a violin plot, or a chart of a messier column are all fair game.
#
# **Your question:** \_\_\_\_\_\_\_\_

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

NAVY = "#22303A"

#
fig, ax = plt.subplots()
sns.regplot(data=students, x="work_hours_per_week", y="final_gpa", color=NAVY, ax=ax)   # which chart? which column(s)?
ax.set_title("Work Hours vs. Final GPA — Northgate Students")
ax.set_xlabel("Work Hours per Week")
ax.set_ylabel("Final GPA")
plt.show()

# --- your code below ---

# %% [markdown]
# **STAR story — Part B** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# S-This chart shows work hours per week with final gpa for Northgate students.
#
# T-Is there a relationship between how much a student works and their final GPA?
#
# A-Clear downward trend: GPA starts around 2.6–2.7 for students working close to 0 hours and declines fairly linearly down to roughly 2.0 for students working 40 hours per week. Clear decline every 10-hour increase in work seems to shave off a similar amount of GPA.
#
# R-Again 0.0 gpa flags first because of the unusal amount and how uncommon that is for most students. A few points sit at negative work hours which is impossible.

# %% [markdown]
# # Before you submit — checklist
# - [ ] The notebook **runs top to bottom** with no errors (Runtime → Restart and run all).
# - [ ] All **6 charts** are present, each with a title, labeled axes, and units/legend where needed.
# - [ ] Each chart has a **complete STAR story**, including any exceptions you spotted.
# - [ ] Part B question is written in and answered.
# - [ ] Pushed to **GitHub**, and the **GitHub link** is submitted in Canvas.
#
# **Rubric (70 pts):** chart choice 10 · correct build 20 · labeling 10 · STAR reading 18 · Part B question 4 · submission & professionalism 8.
